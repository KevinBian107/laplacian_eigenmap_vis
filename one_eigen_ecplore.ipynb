# %% [markdown]
# # MET Explore With 1 Eigenvector (RGB Image)

# %%
# %load_ext autoreload
# %autoreload 2
from dimension_reduction import *

# %%
# takes about 1.5m to run this
root_folder = 'data/MET'
images_array = load_images_from_folders(root_folder)
flattened_color = np.array([image.flatten() for image in images_array])

# %%
np.random.seed(123)
rngs = np.random.choice(30000, 300)
sample = np.array([flattened_color[rng] for rng in rngs])
knn_sol = laplacian_eigenmap(sample, k=35, image_dim=128, radial_func='knn', one_dim=True, num_eigen=0)
gau_sol = laplacian_eigenmap(sample, k=25, image_dim=128, radial_func='kd_kernel_gaussian', one_dim=True, num_eigen=0)

# %%
knn_sol = laplacian_eigenmap(sample, k=30, image_dim=128, radial_func='knn')

# %%
gau_sol = laplacian_eigenmap(sample, k=25, image_dim=128, radial_func='kd_kernel_gaussian')

# %%
import pandas as pd
pd.DataFrame.to_csv(pd.DataFrame(np.arange(10)), 'test_file.csv')
