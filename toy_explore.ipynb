# %% [markdown]
# # Exploratin For Technique of Dimensio Reduction

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dimension_reduction import *

# %%
faces = np.loadtxt("data/faces.csv", delimiter=',')
example_image = faces[0]
plt.figure(figsize=(2.5, 2.5))
plt.imshow(example_image.reshape((64, 64)))
plt.show()

# %%
faces.shape
# Out:
# (400, 4096)

# %% [markdown]
# # Laplacian Eigenmap Toy Example

# %%
laplacian_eigenmap(faces, 20)

# %%
laplacian_eigenmap_3d(faces, 20)
# Out:
# <module 'matplotlib.pyplot' from '/Users/kevinb/miniforge3/envs/dsc80/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Principal Component Analysis Toy Example

# %%
pca_eigen_vector = pca(faces, 5)

# %%
pca_eigen_vector
# Out:
# array([[-0.00417284, -0.02856871,  0.00140022, -0.00118976,  0.02380797],
#        [-0.00708426, -0.03328472, -0.00030273,  0.00176604,  0.02358398],
#        [-0.00932736, -0.03782759, -0.0002029 ,  0.01164279,  0.02220349],
#        ...,
#        [ 0.00018136,  0.02965895, -0.01543191, -0.02943071,  0.04245512],
#        [ 0.00339246,  0.02723949, -0.01373374, -0.02785951,  0.04006432],
#        [ 0.00318019,  0.02490134, -0.01193241, -0.0252332 ,  0.04111208]])

# %%
data_match_principal(faces, pca_eigen_vector)
